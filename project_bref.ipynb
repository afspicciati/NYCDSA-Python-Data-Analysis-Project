# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno

plt.rcParams["figure.figsize"] = (20, 10)

# %%
war_batting = pd.read_csv('war_daily_bat.txt')
war_pitching = pd.read_csv('war_daily_pitch.txt')

# %%
war_batting.keys()
# Out:
# Index(['name_common', 'age', 'mlb_ID', 'player_ID', 'year_ID', 'team_ID',
#        'stint_ID', 'lg_ID', 'PA', 'G', 'Inn', 'runs_bat', 'runs_br', 'runs_dp',
#        'runs_field', 'runs_infield', 'runs_outfield', 'runs_catcher',
#        'runs_good_plays', 'runs_defense', 'runs_position', 'runs_position_p',
#        'runs_replacement', 'runs_above_rep', 'runs_above_avg',
#        'runs_above_avg_off', 'runs_above_avg_def', 'WAA', 'WAA_off', 'WAA_def',
#        'WAR', 'WAR_def', 'WAR_off', 'WAR_rep', 'salary', 'pitcher', 'teamRpG',
#        'oppRpG', 'oppRpPA_rep', 'oppRpG_rep', 'pyth_exponent',
#        'pyth_exponent_rep', 'waa_win_perc', 'waa_win_perc_off',
#        'waa_win_perc_def', 'waa_win_perc_rep', 'OPS_plus', 'TOB_lg', 'TB_lg'],
#       dtype='object')

# %%
missingno.bar(war_batting, figsize=(15,8), fontsize=12, sort='ascending')
# Out:
# <AxesSubplot:>

# %%
plt.bar(war_batting[~war_batting['salary'].isnull()].groupby(by='year_ID').count()['player_ID'].index, war_batting[~war_batting['salary'].isnull()].groupby(by='year_ID').count()['player_ID'])
# Out:
# <BarContainer object of 150 artists>

# %%
plt.bar(war_batting[war_batting['salary'].isnull()].groupby(by='year_ID').count()['player_ID'].index, war_batting[war_batting['salary'].isnull()].groupby(by='year_ID').count()['player_ID'])
# Out:
# <BarContainer object of 152 artists>

# %%
plt.bar(war_batting[~war_batting['salary'].isnull()].groupby(by='year_ID').sum('G')['G'].index, war_batting[~war_batting['salary'].isnull()].groupby(by='year_ID').sum('G')['G'])
# Out:
# <BarContainer object of 150 artists>

# %%
plt.bar(war_batting[war_batting['salary'].isnull()].groupby(by='year_ID').sum('G')['G'].index[-21:], war_batting[war_batting['salary'].isnull()].groupby(by='year_ID').sum('G')['G'][-21:])
# Out:
# <BarContainer object of 21 artists>

# %%
war_batting[war_batting['salary'].isnull()].groupby(by='year_ID').sum('G')['G'].index
# Out:
# Int64Index([1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880,
#             ...
#             2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#            dtype='int64', name='year_ID', length=152)

# %%
batting = pd.read_csv('LahmanData2023\core\Batting.csv')

# %%
war_batting[war_batting['player_ID'] == 'hernafe02'].loc[:,['name_common','year_ID','G','WAR','WAR_def','WAR_off','salary','pitcher']]
# Out:
#            name_common  year_ID  G   WAR  WAR_def  WAR_off      salary pitcher
# 47533  Félix Hernández     2005  0   NaN      NaN      NaN         NaN       Y
# 47534  Félix Hernández     2006  2 -0.07      0.0    -0.07    340000.0       Y
# 47535  Félix Hernández     2007  2  0.01      0.0     0.01    420000.0       Y
# 47536  Félix Hernández     2008  1  0.24      0.0     0.24    540000.0       Y
# 47537  Félix Hernández     2009  2 -0.04      0.0    -0.04   3800000.0       Y
# 47538  Félix Hernández     2010  1 -0.03      0.0    -0.03   7200000.0       Y
# 47539  Félix Hernández     2011  2 -0.02      0.0    -0.02  11700000.0       Y
# 47540  Félix Hernández     2012  1  0.07      0.0     0.07  18500000.0       Y
# 47541  Félix Hernández     2013  2 -0.02      0.0    -0.02  19857000.0       Y
# 47542  Félix Hernández     2014  1 -0.04      0.0    -0.04  22857000.0       Y
# 47543  Félix Hernández     2015  1 -0.04      0.0    -0.04  24857000.0       Y
# ...

# %%
war_pitching[war_pitching['player_ID'] == 'hernafe02'].loc[:,['name_common','year_ID','G','WAR','salary']]
# Out:
#            name_common  year_ID   G   WAR      salary
# 39799  Félix Hernández     2005  12  2.75         NaN
# 40447  Félix Hernández     2006  31  1.33    340000.0
# 41142  Félix Hernández     2007  30  3.93    420000.0
# 41871  Félix Hernández     2008  31  3.99    540000.0
# 42568  Félix Hernández     2009  34  5.92   3800000.0
# 43280  Félix Hernández     2010  34  7.15   7200000.0
# 43981  Félix Hernández     2011  33  3.55  11700000.0
# 44692  Félix Hernández     2012  33  5.26  18500000.0
# 45429  Félix Hernández     2013  31  5.12  19857000.0
# 46159  Félix Hernández     2014  34  6.36  22857000.0
# 46914  Félix Hernández     2015  31  4.55  24857000.0
# 47725  Félix Hernández     2016  25  1.32  25857000.0
# 48578  Félix Hernández     2017  16  0.66  26857000.0
# 49434  Félix Hernández     2018  29 -1.26  26857000.0
# 50336  Félix Hernández     2019  15 -0.76  27858000.0

# %%
war_pitching.keys()
# Out:
# Index(['name_common', 'age', 'mlb_ID', 'player_ID', 'year_ID', 'team_ID',
#        'stint_ID', 'lg_ID', 'G', 'GS', 'IPouts', 'IPouts_start',
#        'IPouts_relief', 'RA', 'xRA', 'xRA_sprp_adj', 'xRA_extras_adj',
#        'xRA_def_pitcher', 'PPF', 'PPF_custom', 'xRA_final', 'BIP', 'BIP_perc',
#        'RS_def_total', 'runs_above_avg', 'runs_above_avg_adj',
#        'runs_above_rep', 'RpO_replacement', 'GR_leverage_index_avg', 'WAR',
#        'salary', 'teamRpG', 'oppRpG', 'pyth_exponent', 'waa_win_perc', 'WAA',
#        'WAA_adj', 'oppRpG_rep', 'pyth_exponent_rep', 'waa_win_perc_rep',
#        'WAR_rep', 'ERA_plus', 'ER_lg'],
#       dtype='object')
